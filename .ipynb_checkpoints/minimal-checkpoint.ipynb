# %% [markdown]
# # Interactive Python using jupyter notebooks

# %% [markdown]
# - Notebooks are made of a sequence of cells
# - Cells can contain different content such as Python code, or Markdown
# - You can change the cell type in the toolbar
# - To execute a cell press "Shift+Return"
# - Use the tool bar to add, delete, copy, or insert cells

# %% [markdown]
# (Note: to learn more about Markdown check [Daring Fireball's website](https://daringfireball.net/projects/markdown/syntax))

# %% [markdown]
# ## Import the Python package for numerical arrays (numpy)

# %%
import numpy as np

# %% [markdown]
# ## Define a function that creates some statistical data

# %%
def load_data():    
    # Goalkeeper, defender, midfielder, attacker
    possible_positions = ['GK', 'D', 'M', 'A']
    N = 100
    positions = []
    heights = []
    for i in range(0,N):
        positions.append(possible_positions[np.random.randint(len(possible_positions))])
        heights.append(np.random.normal(loc=180.0,scale=5.0))
    return positions, heights

# %% [markdown]
# ## Read the data

# %%
positions, heights = load_data()

# %% [markdown]
# The objects ```positions``` and ```heights``` are lists as we can check using the Python function ```type```:

# %%
print(type(positions))
print(type(heights))
# Out:
# <class 'list'>
# <class 'list'>

# %% [markdown]
# Question: *How many items are inside the lists ```positions``` and ```heights```?
#
# Hint: Use the Python function ```len```.

# %%
print(len(positions))
print(len(heights))
# Out:
# 100
# 100

# %% [markdown]
# ## Convert to numpy arrays

# %%
np_positions = np.array(positions)
np_heights = np.array(heights)

# %% [markdown]
# Question: *what is the data type of ```np_positions``` and ```np_heights```*?<br>
# Question: *what is the shape of ```np_positions``` and ```np_heights```*?
#
#
# Hint: Numpy objects have member functions called ```dtype``` and ```shape```.

# %%
print(np_positions.shape)
print(np_heights.shape)
np_heights
# Out:
# (100,)
# (100,)
# array([185.3288744 , 167.05020805, 177.47689068, 175.10122377,
#        195.5543022 , 178.92404774, 188.28921624, 181.63027087,
#        183.22808269, 185.52705279, 170.76542763, 173.41659324,
#        185.24899055, 179.55910682, 170.17039858, 174.99322297,
#        181.03077396, 181.31261642, 175.45558174, 177.18347006,
#        188.74428744, 175.77323859, 177.42664895, 178.3729721 ,
#        179.98490198, 183.64093468, 177.44334725, 178.16129966,
#        173.54400245, 176.33951915, 183.00718422, 184.32726939,
#        175.98375886, 178.49730604, 175.15072829, 183.60220542,
#        194.70877824, 181.65008974, 175.49804506, 190.40046534,
#        184.4452389 , 174.43756464, 189.09862672, 181.58127977,
#        172.20582785, 171.68955354, 176.51653715, 180.3399676 ,
#        186.15885639, 176.37804556, 178.01829425, 176.78231751,
#        176.54810205, 184.5031903 , 186.68791716, 176.8191598 ,
#        181.84547663, 177.7949284 , 174.7033057 , 181.45482537,
#        175.73253128, 188.57911505, 182.88769208, 183.5926434 ,
#        187.05176294, 180.66730347, 186.06166266, 186.01419531,
#        180.06061353, 180.20553036, 185.23545605, 189.09942118,
#        181.0448265 , 189.87077051, 181.95202754, 184.01584242,
#        176.59965007, 173.11349422, 177.80443576, 182.63235512,
#        182.62718402, 181.12403086, 182.51274734, 177.3246782 ,
#        179.11761893, 176.91531949, 175.05675218, 172.45933585,
#        181.5567256 , 176.41244313, 175.96137906, 181.05764529,
#        184.05399826, 162.69059191, 182.0141338 , 175.54083725,
#        176.55234592, 181.183206  , 189.3393344 , 172.59759502])

# %% [markdown]
# ## Extract the heights of the goalkeepers

# %%
gk_heights = np_heights[np_positions == 'GK']
atk_heights = np_heights[np_positions == 'A']
gk_atk_heights = np_heights[(np_positions == 'GK') | (np_positions == 'A')]

# %% [markdown]
# ## Print the median of the goalkeepers heights

# %%
print("Median height of goalkeepers: " + str(np.median(gk_heights)))
print("Median height of attackers: " + str(np.median(atk_heights)))
print("Median height of goalies and attackers combined: " + str(np.median(gk_atk_heights)))
# Out:
# Median height of goalkeepers: 181.17872145974957
# Median height of attackers: 181.58127977242006
# Median height of goalies and attackers combined: 181.55672560103983

# %% [markdown]
# Question: *what is the median height of all the field players*?<br>
# Question: *what is the median height of all the attackers*?<br>
# Question: *what is the median height of goalkeepers and the attackers combined?*

# %% [markdown]
# ## More statistical tests

# %% [markdown]
# Besides the ```median```, numpy als comes with the functions ```mean```, ```std```, ```min``` and ```max``` which are useful for investigating statistical data.

# %% [markdown]
# Question: *Who is the shortest player (which position)*?<br>
# Question: *Who is the tallest player (which position)*?

# %%
shorty = np_positions[np_heights == np.min(np_heights)]
print("The shortest player is a " + str(shorty))
tallguy = np_positions[np_heights == np.max(np_heights)]
print("The shortest player is a " + str(tallguy))
# Out:
# The shortest player is a ['M']
# The shortest player is a ['D']

# %% [markdown]
# ## Data plotting

# %% [markdown]
# For plotting, we need the package matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# There are different display modes for matplotlib plots inside a jupyter notebook.

# %%
# For inline plots use
# %matplotlib inline

# %%
# For inline plots with interactive capabilities use
#%matplotlib notebook

# %% [markdown]
# Lets visualize the height distribution of the defenders

# %%
d_heights = np_heights[np_positions == 'D']

# %%
plt.figure()
plt.hist(d_heights)
plt.title('Defenders')
plt.xlabel('Heights')
plt.show()

# %% [markdown]
# To figure out the tallest/shortest player, we can the max/min within each position

# %%
p = ['GK', 'D', 'M', 'A']
p_max = [np_heights[np_positions == i].max() for i in p]

# %%
plt.figure()
plt.plot(range(len(p)), p_max)
plt.gca().xaxis.set_ticks(range(len(p)))
plt.gca().xaxis.set_ticklabels(p)
plt.ylabel('Heights')
plt.show()

# %% [markdown]
# For inspiration on data plotting and more examples, check out the matplotlib gallery: [https://matplotlib.org/gallery.html](https://matplotlib.org/gallery.html)
